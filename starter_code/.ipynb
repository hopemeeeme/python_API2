# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 588

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#OpenWeather Key
api_key = weather_api_key
units = "imperial"

query_url = f"http://api.openweathermap.org/data/2.5/weather?appid={api_key}&units={units}&q="

# define count of pass throughs
count_one = 0
set_one = 1

print(query_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?appid=9aba8f52f775591a856db4c786f81bb8&units=imperial&q=

# %%
city_two = []
cloudinesses = []
dates = []
humidities = []
lats = []
lngs = []
max_temps = []
wind_speeds = []
countries = []

count_one = 0
set_one = 1

# loops for creating dataframe columns
for city in cities:
    try:
        response = requests.get(query_url + city.replace(" ","&")).json()
        cloudinesses.append(response['clouds']['all'])
        countries.append(response['sys']['country'])
        dates.append(response['dt'])
        humidities.append(response['main']['humidity'])
        lats.append(response['coord']['lat'])
        lngs.append(response['coord']['lon'])
        max_temps.append(response['main']['temp_max'])
        wind_speeds.append(response['wind']['speed'])
        if count_one > 48:
            count_one = 1
            set_one += 1
            city_two.append(city)
        else:
            count_one += 1
            city_two.append(city)
        print(f"Processing Record {count_one} of Set {set_one} | {city}")
    except Exception:
        print("City not found. Skipping...")
print("------------------------------\nData Retrieval Complete\n------------------------------")
# Out:
# Processing Record 1 of Set 1 | excelsior springs
# Processing Record 2 of Set 1 | new norfolk
# Processing Record 3 of Set 1 | shingu
# Processing Record 4 of Set 1 | canico
# Processing Record 5 of Set 1 | cozumel
# Processing Record 6 of Set 1 | hermanus
# Processing Record 7 of Set 1 | talnakh
# City not found. Skipping...
# Processing Record 8 of Set 1 | tuktoyaktuk
# Processing Record 9 of Set 1 | lebu
# Processing Record 10 of Set 1 | ushuaia
# Processing Record 11 of Set 1 | punta arenas
# Processing Record 12 of Set 1 | porto belo
# Processing Record 13 of Set 1 | sorland
# Processing Record 14 of Set 1 | hamilton
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 15 of Set 1 | kaitangata
# Processing Record 16 of Set 1 | rudnya
# Processing Record 17 of Set 1 | bluff
# Processing Record 18 of Set 1 | carauari
# Processing Record 19 of Set 1 | coquimbo
# Processing Record 20 of Set 1 | dikson
# Processing Record 21 of Set 1 | cape town
# Processing Record 22 of Set 1 | atuona
# Processing Record 23 of Set 1 | vaini
# Processing Record 24 of Set 1 | cabo san lucas
# Processing Record 25 of Set 1 | allende
# Processing Record 26 of Set 1 | tumbes
# Processing Record 27 of Set 1 | kapaa
# Processing Record 28 of Set 1 | binzhou
# Processing Record 29 of Set 1 | port blair
# Processing Record 30 of Set 1 | chiredzi
# Processing Record 31 of Set 1 | saint-philippe
# Processing Record 32 of Set 1 | puerto escondido
# Processing Record 33 of Set 1 | yichun
# Processing Record 34 of Set 1 | pevek
# Processing Record 35 of Set 1 | avarua
# Processing Record 36 of Set 1 | port alfred
# Processing Record 37 of Set 1 | berezanka
# Processing Record 38 of Set 1 | kavieng
# Processing Record 39 of Set 1 | sambava
# Processing Record 40 of Set 1 | kodiak
# Processing Record 41 of Set 1 | barrow
# Processing Record 42 of Set 1 | pafos
# Processing Record 43 of Set 1 | qaanaaq
# Processing Record 44 of Set 1 | okhotsk
# Processing Record 45 of Set 1 | bilibino
# Processing Record 46 of Set 1 | esperance
# Processing Record 47 of Set 1 | banda aceh
# Processing Record 48 of Set 1 | kiama
# Processing Record 49 of Set 1 | rikitea
# Processing Record 1 of Set 2 | qui nhon
# Processing Record 2 of Set 2 | marawi
# Processing Record 3 of Set 2 | farafangana
# Processing Record 4 of Set 2 | tam ky
# Processing Record 5 of Set 2 | mizdah
# Processing Record 6 of Set 2 | tuatapere
# Processing Record 7 of Set 2 | axim
# Processing Record 8 of Set 2 | bredasdorp
# Processing Record 9 of Set 2 | busselton
# City not found. Skipping...
# Processing Record 10 of Set 2 | manggar
# City not found. Skipping...
# Processing Record 11 of Set 2 | kalmunai
# Processing Record 12 of Set 2 | mahebourg
# Processing Record 13 of Set 2 | jeremoabo
# Processing Record 14 of Set 2 | west bay
# Processing Record 15 of Set 2 | yellowknife
# Processing Record 16 of Set 2 | mataura
# Processing Record 17 of Set 2 | fort collins
# Processing Record 18 of Set 2 | tasiilaq
# City not found. Skipping...
# Processing Record 19 of Set 2 | san ignacio
# Processing Record 20 of Set 2 | khani
# Processing Record 21 of Set 2 | coihaique
# Processing Record 22 of Set 2 | carnarvon
# Processing Record 23 of Set 2 | cidreira
# Processing Record 24 of Set 2 | yangjiang
# Processing Record 25 of Set 2 | upernavik
# Processing Record 26 of Set 2 | hilo
# Processing Record 27 of Set 2 | launceston
# City not found. Skipping...
# Processing Record 28 of Set 2 | saskylakh
# Processing Record 29 of Set 2 | torbay
# Processing Record 30 of Set 2 | plastun
# Processing Record 31 of Set 2 | codrington
# Processing Record 32 of Set 2 | karratha
# City not found. Skipping...
# Processing Record 33 of Set 2 | eureka
# Processing Record 34 of Set 2 | kaeo
# Processing Record 35 of Set 2 | grindavik
# Processing Record 36 of Set 2 | jamestown
# Processing Record 37 of Set 2 | puerto ayora
# Processing Record 38 of Set 2 | pombia
# Processing Record 39 of Set 2 | waingapu
# Processing Record 40 of Set 2 | halifax
# Processing Record 41 of Set 2 | kununurra
# Processing Record 42 of Set 2 | khatanga
# Processing Record 43 of Set 2 | maraa
# Processing Record 44 of Set 2 | albany
# Processing Record 45 of Set 2 | saint-jean-de-maurienne
# Processing Record 46 of Set 2 | ruwi
# Processing Record 47 of Set 2 | vardo
# Processing Record 48 of Set 2 | svetlogorsk
# Processing Record 49 of Set 2 | srivardhan
# Processing Record 1 of Set 3 | robe
# Processing Record 2 of Set 3 | castro
# Processing Record 3 of Set 3 | ponta do sol
# City not found. Skipping...
# Processing Record 4 of Set 3 | chuy
# Processing Record 5 of Set 3 | hithadhoo
# City not found. Skipping...
# Processing Record 6 of Set 3 | nijar
# Processing Record 7 of Set 3 | cockburn harbour
# Processing Record 8 of Set 3 | georgetown
# Processing Record 9 of Set 3 | sindor
# Processing Record 10 of Set 3 | chulman
# Processing Record 11 of Set 3 | itarema
# Processing Record 12 of Set 3 | souillac
# Processing Record 13 of Set 3 | thompson
# Processing Record 14 of Set 3 | samarai
# Processing Record 15 of Set 3 | lasa
# Processing Record 16 of Set 3 | rongcheng
# Processing Record 17 of Set 3 | adrar
# Processing Record 18 of Set 3 | butaritari
# Processing Record 19 of Set 3 | buraydah
# Processing Record 20 of Set 3 | katangli
# Processing Record 21 of Set 3 | constitucion
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 22 of Set 3 | shenjiamen
# Processing Record 23 of Set 3 | bandarbeyla
# Processing Record 24 of Set 3 | ukiah
# Processing Record 25 of Set 3 | hambantota
# Processing Record 26 of Set 3 | neyshabur
# Processing Record 27 of Set 3 | oussouye
# Processing Record 28 of Set 3 | nome
# Processing Record 29 of Set 3 | piacenza
# Processing Record 30 of Set 3 | geraldton
# Processing Record 31 of Set 3 | saldanha
# Processing Record 32 of Set 3 | antofagasta
# Processing Record 33 of Set 3 | hobart
# Processing Record 34 of Set 3 | chalus
# Processing Record 35 of Set 3 | ostrovnoy
# Processing Record 36 of Set 3 | iqaluit
# Processing Record 37 of Set 3 | kahului
# Processing Record 38 of Set 3 | college
# City not found. Skipping...
# Processing Record 39 of Set 3 | fortuna
# Processing Record 40 of Set 3 | clyde river
# Processing Record 41 of Set 3 | longyearbyen
# City not found. Skipping...
# Processing Record 42 of Set 3 | kostomuksha
# Processing Record 43 of Set 3 | norman wells
# Processing Record 44 of Set 3 | bicske
# Processing Record 45 of Set 3 | manicore
# Processing Record 46 of Set 3 | jieshi
# Processing Record 47 of Set 3 | yar-sale
# Processing Record 48 of Set 3 | qeshm
# Processing Record 49 of Set 3 | arraial do cabo
# Processing Record 1 of Set 4 | mar del plata
# Processing Record 2 of Set 4 | vasto
# Processing Record 3 of Set 4 | presidente dutra
# City not found. Skipping...
# Processing Record 4 of Set 4 | nemuro
# Processing Record 5 of Set 4 | dingle
# Processing Record 6 of Set 4 | xichang
# Processing Record 7 of Set 4 | roald
# Processing Record 8 of Set 4 | petropavlovsk-kamchatskiy
# Processing Record 9 of Set 4 | east london
# Processing Record 10 of Set 4 | lorengau
# Processing Record 11 of Set 4 | san jose
# Processing Record 12 of Set 4 | baruun-urt
# Processing Record 13 of Set 4 | guarapari
# Processing Record 14 of Set 4 | tamiahua
# Processing Record 15 of Set 4 | emba
# Processing Record 16 of Set 4 | itoman
# Processing Record 17 of Set 4 | kangasala
# Processing Record 18 of Set 4 | castelnau-le-lez
# Processing Record 19 of Set 4 | mount gambier
# Processing Record 20 of Set 4 | nanortalik
# Processing Record 21 of Set 4 | port hedland
# Processing Record 22 of Set 4 | airai
# Processing Record 23 of Set 4 | mys shmidta
# Processing Record 24 of Set 4 | bonavista
# Processing Record 25 of Set 4 | faanui
# Processing Record 26 of Set 4 | flinders
# Processing Record 27 of Set 4 | amboasary
# Processing Record 28 of Set 4 | grand-santi
# Processing Record 29 of Set 4 | vardenis
# Processing Record 30 of Set 4 | sitka
# Processing Record 31 of Set 4 | marfino
# Processing Record 32 of Set 4 | grand river south east
# Processing Record 33 of Set 4 | uarini
# Processing Record 34 of Set 4 | mosquera
# Processing Record 35 of Set 4 | naze
# Processing Record 36 of Set 4 | hervey bay
# Processing Record 37 of Set 4 | touros
# Processing Record 38 of Set 4 | morgan city
# Processing Record 39 of Set 4 | bourail
# Processing Record 40 of Set 4 | ribeira grande
# Processing Record 41 of Set 4 | mitsamiouli
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 42 of Set 4 | dawei
# Processing Record 43 of Set 4 | pangnirtung
# City not found. Skipping...
# Processing Record 44 of Set 4 | gat
# City not found. Skipping...
# Processing Record 45 of Set 4 | keetmanshoop
# Processing Record 46 of Set 4 | langham
# Processing Record 47 of Set 4 | yulara
# Processing Record 48 of Set 4 | lafiagi
# Processing Record 49 of Set 4 | kavaratti
# Processing Record 1 of Set 5 | provideniya
# Processing Record 2 of Set 5 | bethel
# Processing Record 3 of Set 5 | nanyang
# Processing Record 4 of Set 5 | berlevag
# Processing Record 5 of Set 5 | sur
# Processing Record 6 of Set 5 | nouadhibou
# Processing Record 7 of Set 5 | xining
# Processing Record 8 of Set 5 | hongjiang
# Processing Record 9 of Set 5 | sao filipe
# Processing Record 10 of Set 5 | fairbanks
# Processing Record 11 of Set 5 | santa maria
# Processing Record 12 of Set 5 | nizhniy odes
# Processing Record 13 of Set 5 | kurchum
# Processing Record 14 of Set 5 | sioux lookout
# Processing Record 15 of Set 5 | puerto cabezas
# Processing Record 16 of Set 5 | guhagar
# Processing Record 17 of Set 5 | ambulu
# Processing Record 18 of Set 5 | bayanday
# Processing Record 19 of Set 5 | mubende
# Processing Record 20 of Set 5 | suez
# City not found. Skipping...
# Processing Record 21 of Set 5 | polyarnyy
# Processing Record 22 of Set 5 | antalaha
# Processing Record 23 of Set 5 | aykhal
# Processing Record 24 of Set 5 | cabedelo
# Processing Record 25 of Set 5 | ilulissat
# Processing Record 26 of Set 5 | yumen
# Processing Record 27 of Set 5 | kaduna
# Processing Record 28 of Set 5 | porto walter
# Processing Record 29 of Set 5 | port elizabeth
# Processing Record 30 of Set 5 | bathsheba
# Processing Record 31 of Set 5 | peterborough
# Processing Record 32 of Set 5 | langres
# Processing Record 33 of Set 5 | keller
# Processing Record 34 of Set 5 | grootfontein
# Processing Record 35 of Set 5 | praia da vitoria
# Processing Record 36 of Set 5 | taut
# Processing Record 37 of Set 5 | meulaboh
# Processing Record 38 of Set 5 | xai-xai
# Processing Record 39 of Set 5 | huarmey
# Processing Record 40 of Set 5 | monze
# Processing Record 41 of Set 5 | katsuura
# Processing Record 42 of Set 5 | nikolskoye
# Processing Record 43 of Set 5 | twin falls
# Processing Record 44 of Set 5 | kapenguria
# Processing Record 45 of Set 5 | singaraja
# City not found. Skipping...
# Processing Record 46 of Set 5 | iquique
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 47 of Set 5 | hilpoltstein
# Processing Record 48 of Set 5 | namibe
# City not found. Skipping...
# Processing Record 49 of Set 5 | bambous virieux
# Processing Record 1 of Set 6 | tual
# Processing Record 2 of Set 6 | vikhorevka
# Processing Record 3 of Set 6 | abu jubayhah
# Processing Record 4 of Set 6 | konin
# Processing Record 5 of Set 6 | changji
# Processing Record 6 of Set 6 | san cristobal
# Processing Record 7 of Set 6 | vilhena
# City not found. Skipping...
# Processing Record 8 of Set 6 | torres
# Processing Record 9 of Set 6 | parry sound
# Processing Record 10 of Set 6 | ust-uda
# Processing Record 11 of Set 6 | chapais
# Processing Record 12 of Set 6 | veraval
# Processing Record 13 of Set 6 | talcahuano
# Processing Record 14 of Set 6 | lincoln
# Processing Record 15 of Set 6 | fare
# Processing Record 16 of Set 6 | coruripe
# Processing Record 17 of Set 6 | belmonte
# Processing Record 18 of Set 6 | narsaq
# Processing Record 19 of Set 6 | at-bashi
# Processing Record 20 of Set 6 | lyuban
# Processing Record 21 of Set 6 | hokitika
# Processing Record 22 of Set 6 | faya
# Processing Record 23 of Set 6 | dogondoutchi
# Processing Record 24 of Set 6 | belyy yar
# Processing Record 25 of Set 6 | vallenar
# Processing Record 26 of Set 6 | bani
# Processing Record 27 of Set 6 | muros
# Processing Record 28 of Set 6 | olinda
# Processing Record 29 of Set 6 | klaksvik
# Processing Record 30 of Set 6 | hearst
# Processing Record 31 of Set 6 | alekseyevsk
# Processing Record 32 of Set 6 | north bend
# Processing Record 33 of Set 6 | dargaville
# Processing Record 34 of Set 6 | zhigansk
# Processing Record 35 of Set 6 | zaozerne
# Processing Record 36 of Set 6 | christchurch
# Processing Record 37 of Set 6 | bengkulu
# City not found. Skipping...
# Processing Record 38 of Set 6 | meget
# Processing Record 39 of Set 6 | kampot
# Processing Record 40 of Set 6 | smithers
# Processing Record 41 of Set 6 | honiara
# Processing Record 42 of Set 6 | bafra
# Processing Record 43 of Set 6 | hami
# Processing Record 44 of Set 6 | skjervoy
# Processing Record 45 of Set 6 | nara
# City not found. Skipping...
# Processing Record 46 of Set 6 | cherskiy
# Processing Record 47 of Set 6 | kasongo-lunda
# Processing Record 48 of Set 6 | altay
# City not found. Skipping...
# Processing Record 49 of Set 6 | kasempa
# Processing Record 1 of Set 7 | mitchelstown
# Processing Record 2 of Set 7 | camacha
# Processing Record 3 of Set 7 | zaragoza
# Processing Record 4 of Set 7 | padang
# Processing Record 5 of Set 7 | arlit
# City not found. Skipping...
# Processing Record 6 of Set 7 | yarada
# Processing Record 7 of Set 7 | pisco
# Processing Record 8 of Set 7 | pirovskoye
# City not found. Skipping...
# Processing Record 9 of Set 7 | nsanje
# Processing Record 10 of Set 7 | bielsk podlaski
# Processing Record 11 of Set 7 | sibolga
# Processing Record 12 of Set 7 | hasaki
# Processing Record 13 of Set 7 | nuevo laredo
# Processing Record 14 of Set 7 | sinnamary
# Processing Record 15 of Set 7 | severo-kurilsk
# Processing Record 16 of Set 7 | broome
# Processing Record 17 of Set 7 | kungurtug
# Processing Record 18 of Set 7 | port lincoln
# City not found. Skipping...
# Processing Record 19 of Set 7 | parkersburg
# Processing Record 20 of Set 7 | whitehorse
# Processing Record 21 of Set 7 | west wendover
# Processing Record 22 of Set 7 | port-gentil
# Processing Record 23 of Set 7 | bafoulabe
# Processing Record 24 of Set 7 | waiuku
# Processing Record 25 of Set 7 | konya
# Processing Record 26 of Set 7 | shelburne
# Processing Record 27 of Set 7 | funtua
# Processing Record 28 of Set 7 | puerto rondon
# Processing Record 29 of Set 7 | bonfim
# Processing Record 30 of Set 7 | hualmay
# Processing Record 31 of Set 7 | magdalena
# Processing Record 32 of Set 7 | ahuimanu
# Processing Record 33 of Set 7 | acapulco
# Processing Record 34 of Set 7 | menongue
# Processing Record 35 of Set 7 | verkh-usugli
# Processing Record 36 of Set 7 | roma
# Processing Record 37 of Set 7 | port-cartier
# Processing Record 38 of Set 7 | albanel
# Processing Record 39 of Set 7 | fort nelson
# Processing Record 40 of Set 7 | strezhevoy
# Processing Record 41 of Set 7 | iquitos
# City not found. Skipping...
# Processing Record 42 of Set 7 | makakilo city
# Processing Record 43 of Set 7 | krasnyy chikoy
# Processing Record 44 of Set 7 | chokurdakh
# Processing Record 45 of Set 7 | pelym
# Processing Record 46 of Set 7 | caravelas
# Processing Record 47 of Set 7 | vila franca do campo
# Processing Record 48 of Set 7 | guerrero negro
# Processing Record 49 of Set 7 | abancay
# Processing Record 1 of Set 8 | ust-karsk
# Processing Record 2 of Set 8 | dwarka
# Processing Record 3 of Set 8 | pacific grove
# Processing Record 4 of Set 8 | mogadishu
# City not found. Skipping...
# Processing Record 5 of Set 8 | laguna
# Processing Record 6 of Set 8 | nordhorn
# Processing Record 7 of Set 8 | barcelona
# Processing Record 8 of Set 8 | waipawa
# Processing Record 9 of Set 8 | crystal beach
# City not found. Skipping...
# Processing Record 10 of Set 8 | moron
# City not found. Skipping...
# Processing Record 11 of Set 8 | shimoda
# Processing Record 12 of Set 8 | sao borja
# Processing Record 13 of Set 8 | babu
# Processing Record 14 of Set 8 | half moon bay
# Processing Record 15 of Set 8 | campbell river
# Processing Record 16 of Set 8 | sobolevo
# Processing Record 17 of Set 8 | macheng
# Processing Record 18 of Set 8 | pathein
# Processing Record 19 of Set 8 | katsuyama
# Processing Record 20 of Set 8 | manaure
# Processing Record 21 of Set 8 | mount isa
# Processing Record 22 of Set 8 | maniitsoq
# Processing Record 23 of Set 8 | isangel
# Processing Record 24 of Set 8 | atbasar
# Processing Record 25 of Set 8 | severnyy
# Processing Record 26 of Set 8 | bosaso
# Processing Record 27 of Set 8 | voznesenye
# City not found. Skipping...
# Processing Record 28 of Set 8 | grand gaube
# Processing Record 29 of Set 8 | talara
# Processing Record 30 of Set 8 | tarata
# Processing Record 31 of Set 8 | lima
# Processing Record 32 of Set 8 | victoria
# Processing Record 33 of Set 8 | kruisfontein
# Processing Record 34 of Set 8 | santa rita
# Processing Record 35 of Set 8 | almaznyy
# Processing Record 36 of Set 8 | tiksi
# Processing Record 37 of Set 8 | sisimiut
# Processing Record 38 of Set 8 | maputo
# City not found. Skipping...
# Processing Record 39 of Set 8 | sidi ali
# Processing Record 40 of Set 8 | salinas
# Processing Record 41 of Set 8 | dhidhdhoo
# Processing Record 42 of Set 8 | lazaro cardenas
# Processing Record 43 of Set 8 | tulum
# Processing Record 44 of Set 8 | formoso do araguaia
# Processing Record 45 of Set 8 | taoudenni
# Processing Record 46 of Set 8 | okha
# Processing Record 47 of Set 8 | mujiayingzi
# Processing Record 48 of Set 8 | verkhnevilyuysk
# Processing Record 49 of Set 8 | paraiso
# Processing Record 1 of Set 9 | jashpurnagar
# Processing Record 2 of Set 9 | casas grandes
# Processing Record 3 of Set 9 | katherine
# Processing Record 4 of Set 9 | dakoro
# City not found. Skipping...
# Processing Record 5 of Set 9 | sanmenxia
# Processing Record 6 of Set 9 | newton
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 7 of Set 9 | lensk
# Processing Record 8 of Set 9 | vavozh
# City not found. Skipping...
# Processing Record 9 of Set 9 | husavik
# Processing Record 10 of Set 9 | ambon
# Processing Record 11 of Set 9 | zhongshu
# Processing Record 12 of Set 9 | burns lake
# Processing Record 13 of Set 9 | colares
# Processing Record 14 of Set 9 | aswan
# Processing Record 15 of Set 9 | panjakent
# Processing Record 16 of Set 9 | khanpur
# Processing Record 17 of Set 9 | ancud
# Processing Record 18 of Set 9 | skibotn
# Processing Record 19 of Set 9 | salalah
# Processing Record 20 of Set 9 | luanda
# Processing Record 21 of Set 9 | bubaque
# Processing Record 22 of Set 9 | vila velha
# City not found. Skipping...
# Processing Record 23 of Set 9 | old road
# Processing Record 24 of Set 9 | starkville
# Processing Record 25 of Set 9 | morehead
# Processing Record 26 of Set 9 | kolpashevo
# City not found. Skipping...
# Processing Record 27 of Set 9 | rio grande
# Processing Record 28 of Set 9 | marechal candido rondon
# Processing Record 29 of Set 9 | kieta
# Processing Record 30 of Set 9 | east wenatchee bench
# City not found. Skipping...
# Processing Record 31 of Set 9 | falkenberg
# Processing Record 32 of Set 9 | vysha
# Processing Record 33 of Set 9 | jumla
# Processing Record 34 of Set 9 | tiarei
# Processing Record 35 of Set 9 | tilichiki
# Processing Record 36 of Set 9 | nishihara
# Processing Record 37 of Set 9 | milkovo
# Processing Record 38 of Set 9 | poum
# Processing Record 39 of Set 9 | voh
# Processing Record 40 of Set 9 | gotsu
# City not found. Skipping...
# Processing Record 41 of Set 9 | sabha
# Processing Record 42 of Set 9 | pocatello
# City not found. Skipping...
# Processing Record 43 of Set 9 | fuling
# Processing Record 44 of Set 9 | warmbad
# Processing Record 45 of Set 9 | kot samaba
# Processing Record 46 of Set 9 | obo
# Processing Record 47 of Set 9 | shasta lake
# Processing Record 48 of Set 9 | newcastle
# Processing Record 49 of Set 9 | saint-joseph
# Processing Record 1 of Set 10 | gimli
# Processing Record 2 of Set 10 | nyurba
# Processing Record 3 of Set 10 | alofi
# Processing Record 4 of Set 10 | ust-maya
# Processing Record 5 of Set 10 | saint-ambroise
# Processing Record 6 of Set 10 | yichang
# Processing Record 7 of Set 10 | wajima
# Processing Record 8 of Set 10 | lewiston
# Processing Record 9 of Set 10 | vysokaya gora
# Processing Record 10 of Set 10 | piraju
# Processing Record 11 of Set 10 | lagoa
# Processing Record 12 of Set 10 | gurupi
# Processing Record 13 of Set 10 | emporia
# Processing Record 14 of Set 10 | alpena
# Processing Record 15 of Set 10 | baykit
# Processing Record 16 of Set 10 | paso de carrasco
# Processing Record 17 of Set 10 | armacao dos buzios
# Processing Record 18 of Set 10 | yamada
# Processing Record 19 of Set 10 | kurumkan
# Processing Record 20 of Set 10 | turukhansk
# Processing Record 21 of Set 10 | sokoto
# Processing Record 22 of Set 10 | apiai
# Processing Record 23 of Set 10 | envira
# Processing Record 24 of Set 10 | tateyama
# Processing Record 25 of Set 10 | sri aman
# Processing Record 26 of Set 10 | dharchula
# Processing Record 27 of Set 10 | haines junction
# Processing Record 28 of Set 10 | hermiston
# Processing Record 29 of Set 10 | fayaoue
# Processing Record 30 of Set 10 | cullera
# Processing Record 31 of Set 10 | san lorenzo
# Processing Record 32 of Set 10 | benito juarez
# Processing Record 33 of Set 10 | bamberg
# Processing Record 34 of Set 10 | bloomington
# Processing Record 35 of Set 10 | san antonio
# Processing Record 36 of Set 10 | xuddur
# City not found. Skipping...
# Processing Record 37 of Set 10 | mitu
# City not found. Skipping...
# Processing Record 38 of Set 10 | bayugan
# Processing Record 39 of Set 10 | vanimo
# Processing Record 40 of Set 10 | lata
# Processing Record 41 of Set 10 | havoysund
# Processing Record 42 of Set 10 | barra patuca
# Processing Record 43 of Set 10 | avera
# Processing Record 44 of Set 10 | ulladulla
# Processing Record 45 of Set 10 | bayevo
# Processing Record 46 of Set 10 | novaya ladoga
# Processing Record 47 of Set 10 | santa margherita ligure
# Processing Record 48 of Set 10 | tura
# Processing Record 49 of Set 10 | raudeberg
# Processing Record 1 of Set 11 | inhambane
# Processing Record 2 of Set 11 | cuenca
# Processing Record 3 of Set 11 | carutapera
# City not found. Skipping...
# Processing Record 4 of Set 11 | matara
# Processing Record 5 of Set 11 | mokrousovo
# Processing Record 6 of Set 11 | sola
# Processing Record 7 of Set 11 | oeiras do para
# Processing Record 8 of Set 11 | nikolayevsk-na-amure
# Processing Record 9 of Set 11 | acatlan
# Processing Record 10 of Set 11 | indramayu
# Processing Record 11 of Set 11 | mahanoro
# Processing Record 12 of Set 11 | asau
# Processing Record 13 of Set 11 | berlin
# Processing Record 14 of Set 11 | weligama
# Processing Record 15 of Set 11 | maketu
# Processing Record 16 of Set 11 | lompoc
# Processing Record 17 of Set 11 | magadan
# City not found. Skipping...
# Processing Record 18 of Set 11 | challans
# Processing Record 19 of Set 11 | alice springs
# Processing Record 20 of Set 11 | baikunthpur
# Processing Record 21 of Set 11 | hastings
# Processing Record 22 of Set 11 | tahe
# Processing Record 23 of Set 11 | san patricio
# Processing Record 24 of Set 11 | monrovia
# Processing Record 25 of Set 11 | champerico
# Processing Record 26 of Set 11 | teguise
# Processing Record 27 of Set 11 | necochea
# Processing Record 28 of Set 11 | lucapa
# Processing Record 29 of Set 11 | kibaya
# Processing Record 30 of Set 11 | north fort myers
# Processing Record 31 of Set 11 | daniel flores
# City not found. Skipping...
# Processing Record 32 of Set 11 | soure
# Processing Record 33 of Set 11 | tukrah
# Processing Record 34 of Set 11 | gorontalo
# Processing Record 35 of Set 11 | redlands
# Processing Record 36 of Set 11 | kupang
# Processing Record 37 of Set 11 | porto santo
# Processing Record 38 of Set 11 | atherton
# Processing Record 39 of Set 11 | rawson
# Processing Record 40 of Set 11 | ebreichsdorf
# Processing Record 41 of Set 11 | olga
# Processing Record 42 of Set 11 | linfen
# Processing Record 43 of Set 11 | makaha
# Processing Record 44 of Set 11 | storslett
# Processing Record 45 of Set 11 | borba
# Processing Record 46 of Set 11 | koumac
# Processing Record 47 of Set 11 | boende
# Processing Record 48 of Set 11 | matagami
# Processing Record 49 of Set 11 | opuwo
# Processing Record 1 of Set 12 | olafsvik
# Processing Record 2 of Set 12 | ewa beach
# Processing Record 3 of Set 12 | mehamn
# Processing Record 4 of Set 12 | cockburn town
# Processing Record 5 of Set 12 | morden
# Processing Record 6 of Set 12 | dankov
# Processing Record 7 of Set 12 | aksu
# Processing Record 8 of Set 12 | lavrentiya
# Processing Record 9 of Set 12 | krasnoselkup
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 10 of Set 12 | berbera
# Processing Record 11 of Set 12 | dutlwe
# Processing Record 12 of Set 12 | hirara
# ------------------------------
# Data Retrieval Complete
# ------------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_dict = {
    "City": city_two,
    "Cloudiness": cloudinesses,
    "Country": countries,
    "Date": dates,
    "Humidity": humidities,
    "Lat": lats,
    "Lng": lngs,
    "Max Temp": max_temps,
    "Wind Speed": wind_speeds
}

# %%
weather_dataframe = pd.DataFrame(weather_dict)

# show the top of the dataframe
weather_dataframe.head(10)
# Out:
#                 City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0  excelsior springs          75      US  1586643590        23  44.90  -93.57
# 1        new norfolk          25      LR  1586643591        84   6.65  -10.59
# 2             shingu         100      JP  1586643591        63  33.73  135.98
# 3             canico          75      PT  1586643591        72  32.63  -16.85
# 4            cozumel          40      MX  1586643591        62  20.51  -86.95
# 5           hermanus         100      ZA  1586643300        67 -34.42   19.23
# 6            talnakh          75      RU  1586643581        80  69.49   88.40
# 7        tuktoyaktuk          20      CA  1586643592        84  69.45 -133.04
# 8               lebu           0      CL  1586643495        55 -37.62  -73.65
# 9            ushuaia          40      AR  1586643552        80 -54.80  -68.30
#
#    Max Temp  Wind Speed
# 0     61.00        3.36
# 1     78.64        3.29
# 2     50.92        6.67
# 3     62.60       13.87
# 4     86.00       12.75
# 5     70.00       18.01
# 6     35.60       31.32
# 7      3.20        6.93
# 8     57.85       16.91
# 9     41.00       23.04

# %%
weather_dataframe.count()
# Out:
# City          551
# Cloudiness    551
# Country       551
# Date          551
# Humidity      551
# Lat           551
# Lng           551
# Max Temp      551
# Wind Speed    551
# dtype: int64

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
#Create a Scatter Plot for Lattitude vs Temperature of City
plt.scatter(weather_dataframe["Lat"], weather_dataframe["Max Temp"], marker='o',s=30, edgecolors= "black")
plt.title("City Latitude vs Max Temperature (04/09/2020)")

plt.ylim(0,100)
plt.xlim(-60, 80)

plt.ylabel("Max. Temperature (F)")
plt.xlabel("Latitude")
plt.grid()
# plt.show()

plt.savefig("LAT VS TEMP.png")

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
#Create a Scatter Plot for Lattitude vs Humidity of City
plt.scatter(weather_dataframe["Lat"], weather_dataframe["Humidity"], marker='o',s=30, edgecolors= "black")
plt.title("City Latitude vs Humidity (04/09/2020)")

plt.ylim(0,150)
plt.xlim(-60, 80)

plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid()
# plt.show()

plt.savefig("LAT VS HUM.png")

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
#Create a Scatter Plot for Lattitude vs Cloudiness of City
plt.scatter(weather_dataframe["Lat"], weather_dataframe["Cloudiness"], marker='o',s=30, edgecolors= "black")
plt.title("City Latitude vs Cloudiness (04/09/2020)")

plt.ylim(0,120)
plt.xlim(-60, 80)

plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid()
# plt.show()

plt.savefig("LAT VS cloudiness.png")

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
#Create a Scatter Plot for Lattitude vs Wind Speed of City
plt.scatter(weather_dataframe["Lat"], weather_dataframe["Wind Speed"], marker='o',s=30, edgecolors= "black")
plt.title("City Latitude vs Wind Speed (04/09/2020)")

plt.ylim(0,40)
plt.xlim(-60, 80)

plt.ylabel("Wind Speed (%)")
plt.xlabel("Latitude")
plt.grid()
# plt.show()

plt.savefig("LAT VS Wind Speed.png")

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots

# %%
def linear_reg_plot(df, title_name, y_column_name, y_label, file_name, xy):
    x_values = df['Lat']
    y_values = df[y_column_name]
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r-")
    plt.xlabel('Latitude')
    plt.ylabel(y_label)
    plt.annotate(line_eq,xy,fontsize=15,color="red")
    plt.title(title_name)
    
    print(f"The r-squared is: {rvalue}")
    
    plt.savefig(file_name)

# %%
# Create Northern and Southern Hemisphere DataFrames
northern_hemisphere_df = weather_dataframe.loc[weather_dataframe['Lat'] > 0, :]
southern_hemisphere_df = weather_dataframe.loc[weather_dataframe['Lat'] < 0, :]
northern_hemisphere_df
# Out:
#                   City  Cloudiness Country        Date  Humidity    Lat  \
# 0    excelsior springs          75      US  1586643590        23  44.90
# 1          new norfolk          25      LR  1586643591        84   6.65
# 2               shingu         100      JP  1586643591        63  33.73
# 3               canico          75      PT  1586643591        72  32.63
# 4              cozumel          40      MX  1586643591        62  20.51
# ..                 ...         ...     ...         ...       ...    ...
# 545               aksu          99      CN  1586643724        20  41.12
# 546         lavrentiya          94      RU  1586643086        98  65.58
# 547       krasnoselkup         100      RU  1586643084        97  65.70
# 548            berbera          22      SO  1586643726        76  10.44
# 550             hirara          75      JP  1586643726        82  24.80
#
#         Lng  Max Temp  Wind Speed
# 0    -93.57     61.00        3.36
# 1    -10.59     78.64        3.29
# 2    135.98     50.92        6.67
# 3    -16.85     62.60       13.87
# 4    -86.95     86.00       12.75
# ..      ...       ...         ...
# 545   80.26     57.85        2.48
# 546 -171.00     31.35       11.30
# 547   82.47     35.76       20.56
# 548   45.01     82.74        4.79
# 550  125.28     66.20       17.22
#
# [388 rows x 9 columns]

# %%
southern_hemisphere_df
# Out:
#               City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 5         hermanus         100      ZA  1586643300        67 -34.42   19.23
# 8             lebu           0      CL  1586643495        55 -37.62  -73.65
# 9          ushuaia          40      AR  1586643552        80 -54.80  -68.30
# 14      kaitangata          92      NZ  1586643420        62 -46.28  169.85
# 16           bluff         100      NZ  1586643065        65 -46.60  168.33
# ..             ...         ...     ...         ...       ...    ...     ...
# 536         boende          98      CD  1586643561        66  -0.22   20.87
# 538          opuwo           5      NA  1586643722        45 -18.06   13.84
# 540      ewa beach          59      ID  1586643723        71  -8.62  122.51
# 542  cockburn town           0      AU  1586643445        70 -32.08  141.00
# 549         dutlwe           3      BW  1586643726        45 -23.98   23.90
#
#      Max Temp  Wind Speed
# 5       70.00       18.01
# 8       57.85       16.91
# 9       41.00       23.04
# 14      56.61        8.95
# 16      57.99        4.00
# ..        ...         ...
# 536     77.50        1.63
# 538     72.28        7.74
# 540     76.50        3.60
# 542     42.80        4.70
# 549     69.22        7.20
#
# [163 rows x 9 columns]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
linear_reg_plot(northern_hemisphere_df, 'Northern Max Temp Vs Latitude Regression', 'Max Temp', 'Max Temp', 'NorthernMaxTempVsLatitudeReg.png', (10,0))
# Out:
# The r-squared is: -0.8739436817812086

# %%
# This linear regression shows that the Max Temperature generally decreases as the latitude goes further away from the equator, which supports our hypothesis for the Northern Hemisphere.

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
linear_reg_plot(southern_hemisphere_df, 'Southern Max Temp Vs Latitude Regression', 'Max Temp', 'Max Temp', 'SouthernMaxTempVsLatitudeReg.png', (-40,50))
# Out:
# The r-squared is: 0.7327212943575446

# %%
# This linear regression shows that the Max Temperature generally decreases as the latitude goes further away from the equator, which supports our hypothesis for the Southern Hemisphere. However, the r-squared is not extremely strong for this data set.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
linear_reg_plot(northern_hemisphere_df, 'Northern Humidity Vs. Latitude Regression', 'Humidity', 'Humidity', 'NorthernHumidityVsLatitudeReg.png', (40,20))
# Out:
# The r-squared is: 0.2929045376287426

# %%
# This linear regression shows that the humidity percent generally decreases as the latitude goes further away from the equator, but the r-squared is not very high for this making it difficult to determine if the data accurately portrays this or not.

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
linear_reg_plot(southern_hemisphere_df, 'Southern Humidity Vs. Latitude Regression', 'Humidity', 'Humidity', 'SouthernHumidityVsLatitudeReg.png', (-50,20))
# Out:
# The r-squared is: 0.2899637283110326

# %%
# This linear regression suggests that the humidity percent increases as we get closer to the equator, but this is probably not exactly the case since the r-squared is not strong.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
linear_reg_plot(northern_hemisphere_df, 'Northern Cloudiness Vs. Latitude Regression', 'Cloudiness', 'Cloudiness', 'NorthernCloudinessVsLatitudeReg.png', (40,20))
# Out:
# The r-squared is: 0.2415673894080067

# %%
# This linear regression suggests that the cloudiness percent increases as we get further from the equator, but this is probably not exactly the case since the r-squared is not strong.

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
linear_reg_plot(southern_hemisphere_df, 'Southern Cloudiness Vs. Latitude Regression', 'Cloudiness', 'Cloudiness', 'SouthernCloudinessVsLatitudeReg.png', (-50,20))
# Out:
# The r-squared is: 0.22189803984046785

# %%
# This linear regression suggests that the cloudiness percent decreases as we get further from the equator, but this is probably not exactly the case since the r-squared is not strong.

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
linear_reg_plot(northern_hemisphere_df, 'Northern Wind Speed Vs. Latitude Regression', 'Wind Speed', 'Wind Speed', 'NorthernWindSpeedVsLatitudeReg.png', (40,20))
# Out:
# The r-squared is: 0.11561702260466337

# %%
# This linear regression suggests that the wind speed slightly increases as we get further from the equator, but this is likely not exactly the case since the r-squared is not strong.

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
linear_reg_plot(southern_hemisphere_df, 'Southern Wind Speed Vs. Southern Hemisphere', 'Wind Speed', 'Wind Speed', 'SouthernWindSpeedVsLatitudeReg.png', (-30,20))
# Out:
# The r-squared is: -0.42448765969621327

# %%
# This linear regression suggests that the wind speed slightly increases as we get further from the equator, but this is likely not exactly the case since the r-squared is not strong.
